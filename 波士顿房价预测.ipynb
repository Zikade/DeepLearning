# %%
import numpy as np
import tensorflow as tf

# %%
(train_data, train_label), (test_data, test_label) =\
    tf.keras.datasets.boston_housing.load_data()

# %%
train_data.shape
# Out:
# (404, 13)

# %%
train_label.shape
# Out:
# (404,)

# %%
with tf.Graph().as_default() as g:
    inputs = tf.placeholder(shape=[None, 13], dtype=tf.float32)
    labels = tf.placeholder(shape=[None], dtype=tf.float32)
    
    h1 = tf.keras.layers.Dense(64, activation=tf.nn.relu)(inputs)
    h2 = tf.keras.layers.Dense(16, activation=tf.nn.relu)(h1)
    output = tf.keras.layers.Dense(1, activation=None)(h2)
    
    loss = tf.reduce_mean(
        tf.keras.losses.mean_squared_error(labels, output))
    
    optim = tf.train.GradientDescentOptimizer(learning_rate=1e-6)
    train_op = optim.minimize(loss)

with tf.Session(graph=g) as sess:
    sess.run(tf.global_variables_initializer())
    batch_size= 32
    for epoch in range(200):
        order = np.argsort(np.random.random(train_label.shape))
        train_data = train_data[order]
        train_label = train_label[order]
        
        res_train_losses = []
        for i in range(train_label.shape[0] // batch_size):
            start = i * batch_size
            end = (i + 1) * batch_size
            res_train_loss, _ = sess.run([loss, train_op],
                     feed_dict={inputs: train_data[start: end],
                                labels: train_label[start: end]})
            res_train_losses.append(res_train_loss)
        res_val_loss = sess.run(loss,
                 feed_dict={inputs: test_data,
                            labels: test_label})
        print('epoch %3d, train loss %2.4f, val loss %2.4f' %
              (epoch, res_train_loss, np.mean(res_train_losses)))
# Out:
# epoch   0, train loss 145.2481, val loss 945.2979
# epoch   1, train loss 162.5105, val loss 141.1525
# epoch   2, train loss 99.3239, val loss 116.6555
# epoch   3, train loss 117.8308, val loss 106.9006
# epoch   4, train loss 117.4771, val loss 99.0294
# epoch   5, train loss 104.7549, val loss 95.8763
# epoch   6, train loss 77.9163, val loss 93.6971
# epoch   7, train loss 146.8934, val loss 96.1000
# epoch   8, train loss 87.9068, val loss 93.4932
# epoch   9, train loss 85.6922, val loss 94.6506
# epoch  10, train loss 73.1195, val loss 90.7659
# epoch  11, train loss 76.7400, val loss 91.7628
# epoch  12, train loss 19.9785, val loss 91.5510
# epoch  13, train loss 81.2280, val loss 90.1124
# epoch  14, train loss 101.8735, val loss 91.4321
# epoch  15, train loss 101.8596, val loss 90.7444
# epoch  16, train loss 134.5370, val loss 91.6329
# epoch  17, train loss 99.3723, val loss 88.1104
# epoch  18, train loss 60.1031, val loss 88.8686
# epoch  19, train loss 99.5049, val loss 93.4195
# epoch  20, train loss 96.8509, val loss 89.1346
# epoch  21, train loss 65.6753, val loss 84.0502
# epoch  22, train loss 93.4674, val loss 89.5598
# epoch  23, train loss 106.8973, val loss 89.7938
# epoch  24, train loss 96.9620, val loss 89.9461
# epoch  25, train loss 75.7271, val loss 93.0851
# epoch  26, train loss 96.4135, val loss 84.4162
# epoch  27, train loss 118.4826, val loss 88.3316
# epoch  28, train loss 120.9144, val loss 91.3540
# epoch  29, train loss 115.8831, val loss 87.4156
# epoch  30, train loss 70.5655, val loss 85.5901
# epoch  31, train loss 108.3143, val loss 90.2865
# epoch  32, train loss 56.8460, val loss 89.9835
# epoch  33, train loss 85.9266, val loss 91.0684
# epoch  34, train loss 69.8165, val loss 88.6865
# epoch  35, train loss 65.6390, val loss 89.2352
# epoch  36, train loss 65.3792, val loss 90.6918
# epoch  37, train loss 112.4569, val loss 87.8116
# epoch  38, train loss 92.8475, val loss 90.0205
# epoch  39, train loss 106.6255, val loss 87.1209
# epoch  40, train loss 93.2575, val loss 86.5493
# epoch  41, train loss 67.9913, val loss 89.3216
# epoch  42, train loss 115.6813, val loss 84.5668
# epoch  43, train loss 98.2233, val loss 86.6627
# epoch  44, train loss 90.2074, val loss 90.3057
# epoch  45, train loss 119.5138, val loss 87.7279
# epoch  46, train loss 37.8184, val loss 89.8413
# epoch  47, train loss 71.4448, val loss 90.3383
# epoch  48, train loss 66.4293, val loss 89.8042
# epoch  49, train loss 116.5237, val loss 89.8034
# epoch  50, train loss 91.5225, val loss 83.1808
# epoch  51, train loss 104.1242, val loss 88.8507
# epoch  52, train loss 66.2120, val loss 87.4714
# epoch  53, train loss 76.5269, val loss 89.4547
# epoch  54, train loss 119.4902, val loss 81.7122
# epoch  55, train loss 50.3103, val loss 87.8062
# epoch  56, train loss 117.7418, val loss 89.8046
# epoch  57, train loss 76.3176, val loss 88.3257
# epoch  58, train loss 92.4010, val loss 87.9271
# epoch  59, train loss 70.3421, val loss 89.0335
# epoch  60, train loss 96.3867, val loss 90.4574
# epoch  61, train loss 95.3953, val loss 88.7792
# epoch  62, train loss 84.9619, val loss 90.8482
# epoch  63, train loss 161.4857, val loss 88.4775
# epoch  64, train loss 84.9821, val loss 88.6832
# epoch  65, train loss 76.7509, val loss 92.5599
# epoch  66, train loss 41.6724, val loss 86.6750
# epoch  67, train loss 59.1623, val loss 85.5131
# epoch  68, train loss 125.6027, val loss 87.7713
# epoch  69, train loss 86.1297, val loss 85.9501
# epoch  70, train loss 69.4808, val loss 88.5650
# epoch  71, train loss 109.0036, val loss 88.5741
# epoch  72, train loss 66.6570, val loss 89.1069
# epoch  73, train loss 54.0690, val loss 89.6148
# epoch  74, train loss 59.0088, val loss 86.1712
# epoch  75, train loss 77.8153, val loss 88.1454
# epoch  76, train loss 53.3146, val loss 89.4062
# epoch  77, train loss 80.9101, val loss 89.1010
# epoch  78, train loss 99.7752, val loss 90.6006
# epoch  79, train loss 114.1388, val loss 89.6882
# epoch  80, train loss 91.5036, val loss 88.9522
# epoch  81, train loss 58.1816, val loss 87.8810
# epoch  82, train loss 135.2171, val loss 88.6450
# epoch  83, train loss 39.7080, val loss 84.5614
# epoch  84, train loss 83.3084, val loss 90.0317
# epoch  85, train loss 46.6011, val loss 87.8243
# epoch  86, train loss 47.7877, val loss 86.7912
# epoch  87, train loss 88.6339, val loss 85.4996
# epoch  88, train loss 46.1727, val loss 90.4943
# epoch  89, train loss 59.0882, val loss 87.1474
# epoch  90, train loss 139.1301, val loss 85.6256
# epoch  91, train loss 118.0932, val loss 88.6297
# epoch  92, train loss 71.3981, val loss 90.5999
# epoch  93, train loss 76.2641, val loss 88.1532
# epoch  94, train loss 61.1549, val loss 84.6165
# epoch  95, train loss 114.4117, val loss 90.4351
# epoch  96, train loss 62.3493, val loss 88.9562
# epoch  97, train loss 76.9500, val loss 83.6348
# epoch  98, train loss 132.5775, val loss 91.0489
# epoch  99, train loss 81.2115, val loss 88.3864
# epoch 100, train loss 76.7441, val loss 87.3120
# epoch 101, train loss 123.0635, val loss 89.6440
# epoch 102, train loss 144.8605, val loss 84.6419
# epoch 103, train loss 92.5434, val loss 89.4277
# epoch 104, train loss 107.0291, val loss 87.3693
# epoch 105, train loss 112.4347, val loss 85.8213
# epoch 106, train loss 98.3766, val loss 86.7764
# epoch 107, train loss 95.0703, val loss 86.4628
# epoch 108, train loss 69.1472, val loss 84.5055
# epoch 109, train loss 107.6476, val loss 86.4335
# epoch 110, train loss 102.1725, val loss 86.6233
# epoch 111, train loss 150.4606, val loss 89.2149
# epoch 112, train loss 73.2331, val loss 88.3560
# epoch 113, train loss 121.3417, val loss 88.6335
# epoch 114, train loss 107.0443, val loss 87.5904
# epoch 115, train loss 78.5466, val loss 86.2829
# epoch 116, train loss 85.4038, val loss 86.4600
# epoch 117, train loss 76.6167, val loss 88.9370
# epoch 118, train loss 70.9212, val loss 88.0031
# epoch 119, train loss 103.6262, val loss 89.1792
# epoch 120, train loss 64.4097, val loss 88.8874
# epoch 121, train loss 101.9846, val loss 86.9219
# epoch 122, train loss 108.6755, val loss 89.2847
# epoch 123, train loss 83.7195, val loss 86.5145
# epoch 124, train loss 64.9525, val loss 85.5069
# epoch 125, train loss 68.5910, val loss 89.4852
# epoch 126, train loss 73.1021, val loss 86.8788
# epoch 127, train loss 72.1713, val loss 87.7762
# epoch 128, train loss 69.6591, val loss 88.7547
# epoch 129, train loss 132.2684, val loss 87.3535
# epoch 130, train loss 86.5439, val loss 89.2306
# epoch 131, train loss 36.6648, val loss 87.4098
# epoch 132, train loss 106.2995, val loss 82.9321
# epoch 133, train loss 85.8503, val loss 88.3884
# epoch 134, train loss 103.8258, val loss 84.8168
# epoch 135, train loss 77.6814, val loss 90.1683
# epoch 136, train loss 96.6846, val loss 88.6351
# epoch 137, train loss 81.6563, val loss 89.5369
# epoch 138, train loss 84.3263, val loss 88.4544
# epoch 139, train loss 98.6860, val loss 88.0872
# epoch 140, train loss 61.0200, val loss 89.9000
# epoch 141, train loss 123.1835, val loss 80.9313
# epoch 142, train loss 102.5017, val loss 90.8467
# epoch 143, train loss 122.0539, val loss 89.4377
# epoch 144, train loss 107.1010, val loss 87.0973
# epoch 145, train loss 113.1343, val loss 87.1007
# epoch 146, train loss 93.0199, val loss 88.3045
# epoch 147, train loss 131.1372, val loss 89.8792
# epoch 148, train loss 85.3893, val loss 89.2700
# epoch 149, train loss 58.5017, val loss 85.2396
# epoch 150, train loss 68.2735, val loss 84.5218
# epoch 151, train loss 116.8147, val loss 86.6161
# epoch 152, train loss 64.0450, val loss 86.2453
# epoch 153, train loss 31.9971, val loss 85.7039
# epoch 154, train loss 142.6211, val loss 90.0917
# epoch 155, train loss 70.1468, val loss 87.3675
# epoch 156, train loss 118.2062, val loss 87.4498
# epoch 157, train loss 134.7055, val loss 86.2350
# epoch 158, train loss 68.5976, val loss 85.4328
# epoch 159, train loss 54.6559, val loss 89.9726
# epoch 160, train loss 89.0717, val loss 83.7131
# epoch 161, train loss 64.8484, val loss 88.5453
# epoch 162, train loss 101.5330, val loss 88.1227
# epoch 163, train loss 65.9965, val loss 86.0511
# epoch 164, train loss 92.5836, val loss 90.6600
# epoch 165, train loss 89.8236, val loss 88.6061
# epoch 166, train loss 92.4628, val loss 90.9631
# epoch 167, train loss 91.6829, val loss 84.8212
# epoch 168, train loss 38.3418, val loss 89.5366
# epoch 169, train loss 133.6565, val loss 89.8199
# epoch 170, train loss 56.0893, val loss 87.3003
# epoch 171, train loss 77.0526, val loss 87.1468
# epoch 172, train loss 70.9595, val loss 89.3003
# epoch 173, train loss 63.6332, val loss 85.9729
# epoch 174, train loss 107.3566, val loss 91.0155
# epoch 175, train loss 100.5017, val loss 86.3353
# epoch 176, train loss 51.6222, val loss 86.5047
# epoch 177, train loss 138.6524, val loss 89.3986
# epoch 178, train loss 61.1550, val loss 86.1085
# epoch 179, train loss 87.4743, val loss 90.0638
# epoch 180, train loss 65.5135, val loss 87.3184
# epoch 181, train loss 144.5299, val loss 88.8604
# epoch 182, train loss 97.6273, val loss 89.7386
# epoch 183, train loss 138.1215, val loss 85.3343
# epoch 184, train loss 132.1315, val loss 86.7279
# epoch 185, train loss 71.2074, val loss 89.4612
# epoch 186, train loss 37.3379, val loss 86.3806
# epoch 187, train loss 81.9532, val loss 85.8892
# epoch 188, train loss 87.0817, val loss 88.1266
# epoch 189, train loss 91.6563, val loss 86.0460
# epoch 190, train loss 101.0352, val loss 87.5313
# epoch 191, train loss 104.8325, val loss 87.7139
# epoch 192, train loss 117.3620, val loss 89.9501
# epoch 193, train loss 96.1933, val loss 90.1795
# epoch 194, train loss 99.6419, val loss 89.8778
# epoch 195, train loss 125.1176, val loss 88.2862
# epoch 196, train loss 79.3801, val loss 89.0653
# epoch 197, train loss 68.6551, val loss 91.3523
# epoch 198, train loss 87.6234, val loss 88.4539
# epoch 199, train loss 78.8085, val loss 89.1500

# %% [markdown]
# ## 作业
#
# 1. 复现上述房价预测代码
# 2. 为上述模型训练添加代价变化的`TensorBoard`摘要
# 3. 导入`Fashion_MNIST`数据集并可视化
# 4. 构建全连接神经网络并使用导入的数据训练分类器
# 5. 尝试改进神经网络的结构与训练方法提高模型性能
#
#
# 提示：可使用`tf.keras.datasets.fashion_mnist.load_data()`导入数据
